# %% [markdown]
# # Pengajaran: Isolasi DNA

# %%
import yaml
import pandas as pd

# %% [markdown]
# prosedure + lokasinya dimana

# %% [markdown]
# ## Persiapan

# %% [markdown]
# ### Pengumuman
#
# - Memberitahu praktikan agar mencetak/mencatat prosedur-prosedur isolasi DNA yang tercantum di modul, serta memahaminya.

# %% [markdown]
# ### Pembuatan CTAB Buffer

# %% [markdown]
# ### Alur Pengajaran

# %%
#| label: tbl:alurpengajaran-isolasidna
#| tags: [remove-cell]

# Alur pengajaran

yaml_data="""
alur_pengajaran:
    -   urutan              : 0
        sesi                : Pengumuman dan Persiapan
        "durasi (menit)"    : 
        keterangan          : Sebelum praktikum
    
    -   urutan              : 1
        sesi                : Pre-Test
        "durasi (menit)"    : 10
        keterangan          :

    -   urutan              : 2
        sesi                : Pendahuluan dan Pematerian
        "durasi (menit)"    : 10
        keterangan          :

    -   urutan              : 3
        sesi                : Kegiatan Inti
        "durasi (menit)"    : 80
        keterangan          :

    -   urutan              : 5
        sesi                : Post-Test
        "durasi (menit)"    : 10
        keterangan          :

    -   urutan              : 6
        sesi                : Penutup
        keterangan          :
"""
# 1. Parse the YAML data
parsed_yaml = yaml.safe_load(yaml_data)
# 2. Access the specific nested list under 'alur_pengajaran'
data_list = parsed_yaml["alur_pengajaran"]
# 3. Convert to DataFrame
df = pd.DataFrame(data_list)
# 4. Fill empty/None values with a blank space for better presentation
df = df.fillna("")
# 5. Display the table

df

# %% [markdown]
# :::{table} Alur pengajaran praktikum
# :label: tbl:alur-pengajaran
# ![](#tbl:alurpengajaran-isolasidna)
# :::

# %% [markdown]
# ### Yang perlu dipersiapkan

# %% [markdown]
# #### Stasiun Kerja

# %% [markdown]
# #### Alat dan Bahan

# %% [markdown]
# - [ ] Persiapkan alat dan bahan. kemudian, sebelum praktikum dimulai hari itu, taruh alat dan bahan di lab sentral
# - [ ] Water bath
# - [ ] Pastikan alat-alat yang dipinjamkan (seperti sentrifuge) harus ada yang mengawasi
# - [ ] Pastikan Laboran sudah ada di area alat-alat yang dipinjamkan

# %% [markdown]
# ## Pendahuluan & Pematerian

# %% [markdown]
# - Apa saja yg harus dijelaskan
#     - Prosedur isolasi mengikuti modul yang disesuaikan dgn arahan asisten (karena ada beberapa pengubahan dari modul yang diberikan)
#     - Setiap ketua kelompok bertanggung jawab untuk memimpin selama prosedur.
#
# Beritahu praktikan bahwa:
# > "Prosedur yang tercantum disini merupakan: modifikasi dari beberapa referensi; penyesuaian terhadap waktu praktikum yang tersedia dan; penyesuaian terhadap alat dan bahan yang tersedia"

# %% [markdown]
# Setelah pendahuluan/pematerian, asisten membagikan mikrotub.
# bagaimana pembagian mikrotubnya?

# %% [markdown]
# ## Kegiatan Inti

# %% [markdown]
# Sebelum kegiatan inti dimulai, beritahukan bahwa:
#
# - Praktikan harus mempercepat pergerakan, mempertimbangkan waktu yang tersedia itu sedikit.
# -

# %% [markdown]
# Praktikum tidak dilakukan di lab biotek.
# Setidaknya, ada 3 asisten yang hadir dalam acara ini untuk mengawasi tiap sampel.
# Asisten memegang mikropipet & menuangkan larutan.
