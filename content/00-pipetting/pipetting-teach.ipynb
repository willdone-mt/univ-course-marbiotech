# %% [markdown]
# # Pengajaran: Mikropipet dan Pipetting

# %%
import pandas as pd
import yaml

# %% [markdown]
# ### Alur Pengajaran

# %%
# Alur pengajaran

yaml_data="""
alur_pengajaran:
    -   urutan              : 0
        sesi                : Pengumuman
        "durasi (menit)"    : 
        keterangan          :
    
    -   urutan              : 1
        sesi                : Pre-Test
        "durasi (menit)"    : 15
        keterangan          :

    -   urutan              : 2
        sesi                : "Pendahuluan dan Pematerian"
        "durasi (menit)"    : 15
        keterangan          :

    -   urutan              : 3
        sesi                : Demonstrasi
        "durasi (menit)"    : 20
        keterangan          :

    -   urutan              : 4
        sesi                : Penilaian Keterampilan
        "durasi (menit)"    : 50
        keterangan          :

    -   urutan              : 5
        sesi                : Post-Test
        "durasi (menit)"    : 15
        keterangan          :

    -   urutan              : 6
        sesi                : Penutup
        "durasi (menit)"    : 5
        keterangan          :
"""
# 1. Parse the YAML data
parsed_yaml = yaml.safe_load(yaml_data)

# 2. Access the specific nested list under 'alur_pengajaran'
data_list = parsed_yaml["alur_pengajaran"]

# 3. Convert to DataFrame
df = pd.DataFrame(data_list)

# 4. Fill empty/None values with a blank space for better presentation
df = df.fillna("")

# 5. Display the table
df
# Out:
#    urutan                        sesi durasi (menit) keterangan
# 0       0                  Pengumuman
# 1       1                    Pre-Test           15.0
# 2       2  Pendahuluan dan Pematerian           15.0
# 3       3                 Demonstrasi           20.0
# 4       4      Penilaian Keterampilan           50.0
# 5       5                   Post-Test           15.0
# 6       6                     Penutup            5.0

# %% [markdown]
# ## Pendahuluan dan Pematerian

# %% [markdown]
# Sesi diskusi bersama praktikan.
#
# Asisten memberikan pertanyaan, praktikan menjawab (Asisten mencatat).
# Asisten merespon dengan mengkonfirmasi (benar atau salah), ataupun menambahkan.
# Menambahkan dapat berupa menambahkan informasi, ataupun meminta kepada praktikan lain untuk menambahkan

# %% [markdown]
# Yang perlu didiskusikan:
#
# - Komponen/Anatomi Mikropipet
# -

# %% [markdown]
# Apabila hal yang perlu didiskusikan sudah habis, SEMENTARA waktu yang direncakan belum habis, maka langsung dilanjutkan sesi selanjutnya

# %% [markdown]
# Di akhir sesi, asisten menyuarakan prosedur penggunaan mikropipet

# %% [markdown]
# ## Demonstrasi

# %% [markdown]
# Asisten mempraktekkan dan menyuarakan prosedur yang sudah ditetapkan di petunjuk praktikum.
# Sembari mempraktekan, asisten menambahkan beberapa informasi yang perlu diketahui oleh praktikkan
#
# Prosedur Penggunan Mikropipet terdapat [disini](pipetting-course.md#prosedur-penggunaan)

# %% [markdown]
# ### Sesi Latihan

# %% [markdown]
# ## Penilaian

# %% [markdown]
# :::{admonition} Post tes buat teori, penilaian khusus menilai teknikal
# :class: note
# :::

# %% [markdown]
# **Prosedur Penilaian**:
#
# 1. Praktikkan menyiapkan kertas kosong, kemudian mengisinya dengan:
#    1. Nama
#    2. NIM
#    3. Kelompok
#    4. Asisten
#    5. Tanggal
#    6. Kriteria Penilaian
# 2. Praktikan yang mendapatkan giliran maju, memberikan kertas tersebut, dan mempraktekannya

# %% [markdown]
# ### **Kriteria Penilaian**:
#
# 1. Cara memutar
# 2. Cara mengatur
# 3. Ketepatan
# 4. Cara menggunakan setelah dipakai
#    1.  buang tip sama dibalikkin lagi ke volume maksimalnya aja kaa
# 5.
#
#
# > [!NOTE]
# > Proposed Scoring
# >
# > 1. Ketepatan mengikuti prosedur
# > 2. Kehati-hatian dalam memutar _volume adjustment_

# %% [markdown]
# ## Post Test

# %% [markdown]
# ## Penutup

# %% [markdown]
# :::{tip}
# **Proses belajar** membutuhkan kebebasan untuk **salah**, tetapi **tujuan belajar** adalah memahami mana yang **benar**.
# :::
