# %% [markdown]
# # Pengajaran: Mikropipet dan Pipetting

# %%
import pandas as pd
import yaml

# %% [markdown]
# ## Persiapan

# %% [markdown]
# ### Pengumuman

# %% [markdown]
# ### Alur Pengajaran

# %%
# Alur pengajaran

yaml_data="""
alur_pengajaran:
    -   urutan              : 0
        sesi                : Pengumuman dan Persiapan
        "durasi (menit)"    : 
        keterangan          : Sebelum praktikum
    
    -   urutan              : 1
        sesi                : Pre-Test
        "durasi (menit)"    : 15
        keterangan          :

    -   urutan              : 2
        sesi                : Pendahuluan dan Pematerian
        "durasi (menit)"    : 10
        keterangan          :

    -   urutan              : 3
        sesi                : Demonstrasi
        "durasi (menit)"    : 10
        keterangan          :

    -   urutan              : 4
        sesi                : Penilaian Keterampilan
        "durasi (menit)"    : 60
        keterangan          :

    -   urutan              : 5
        sesi                : Post-Test
        "durasi (menit)"    : 15
        keterangan          :

    -   urutan              : 6
        sesi                : Penutup
        "durasi (menit)"    : 5
        keterangan          :
"""
# 1. Parse the YAML data
parsed_yaml = yaml.safe_load(yaml_data)
# 2. Access the specific nested list under 'alur_pengajaran'
data_list = parsed_yaml["alur_pengajaran"]
# 3. Convert to DataFrame
df = pd.DataFrame(data_list)
# 4. Fill empty/None values with a blank space for better presentation
df = df.fillna("")
# 5. Display the table
df

# %% [markdown]
# ### Yg perlu dipersiapkan

# %% [markdown]
# #### Stasiun Kerja
#
# - [ ] Lab Pendidikan dan Pengajaran 5 (Sentral IKL), lokasi sesi-sesi penjelasan
# - [ ] Lab Pendidikan dan Pengajaran 4 (Lab Biotek IKL), lokasi penilaian

# %% [markdown]
# #### Alat dan Bahan
#
# - [ ] Mikropipet
# - [ ] Pipet Tip
# - [ ] Mangkuk Lab, sebagai wadah penampung cairan
# - [ ] Air kran biasa, sebagai cairan latihan

# %% [markdown]
# ## Pendahuluan dan Pematerian

# %% [markdown]
# Sesi diskusi bersama praktikan, di Lab Sentral.
#
# Asisten memberikan pertanyaan, praktikan menjawab (Asisten mencatat).
# Asisten merespon dengan mengkonfirmasi (benar atau salah), ataupun menambahkan.
# Menambahkan dapat berupa menambahkan informasi, ataupun meminta kepada praktikan lain untuk menambahkan

# %% [markdown]
# Yang perlu didiskusikan:
#
# - Pemahaman praktikan terhadap penggunaan mikropipet
# - Status pengajuan artikel jurnal untuk projek 1
# - Komponen/Anatomi Mikropipet
#
# <!--
# Apabila salah satu praktikan membawa modul acara 1,
# maka diminta org disampingnya untuk membacakan beberapa bagian dari modul.
# -->
#
# Apabila hal yang perlu didiskusikan sudah habis, SEMENTARA waktu yang direncakan belum habis, maka langsung dilanjutkan sesi selanjutnya

# %% [markdown]
# Di akhir sesi, asisten menyuarakan prosedur penggunaan mikropipet

# %% [markdown]
# ## Demonstrasi

# %% [markdown]
# Demonstrasi dilakukan di Lab Sentral.
#
# Asisten mempraktekkan dan menyuarakan prosedur yang sudah ditetapkan di petunjuk praktikum.
# Sembari mempraktekan, asisten menambahkan beberapa informasi yang perlu diketahui oleh praktikkan
#
# Demonstrasi dilakukan di bagian ruangan yang praktikkan dapat melihat secara jelas.
#
# :::{tip} Ide
#
# Karena alat dan bahan di acara ini hanya sedikit, demonstrasi dapat dilakukan di daerah pintu (bagian selatan) di ruangan tersebut,
# dengan kursi tinggi sebagai tatakannya.
#
# :::
#
# Prosedur Penggunan Mikropipet terdapat [disini](pipetting-course.md)

# %% [markdown]
# Setelah demonstrasi, 1 - 2 org diajak untuk mencoba.
# Tanpa ada sesi latihan.

# %% [markdown]
# ## Penilaian

# %% [markdown]
# :::{admonition} Post tes buat teori, penilaian khusus menilai teknikal
# :class: note
# :::
#
# Penjelasan dilakukan di lab sentral, sedangkan penilaian dipanggil ke dan dilakukan di lab biotek
#
# Setelah sesi demonstrasi, praktikan diminta untuk mengingat dan memahami penggunaan mikropipet.
# Bagi yg sudah siap, dipersilahkan untuk maju, ataupun asprak bisa memanggil praktikan.

# %% [markdown]
# #### Prosedur Penilaian
#
# Jumlah praktikan yg diuji sejumlah asprak.
# (ada dua  asprak, jadi yg diuji hanya 2 praktikan tiap waktunya).
#
#
#
# 1. Praktikkan menyiapkan kertas kosong, kemudian mengisinya dengan:
#    1. Nama
#    2. NIM
#    3. Kelompok
#    4. Asisten
#    5. Tanggal
#    6. Kriteria Penilaian
# 2. Praktikkan yang menunggu giliran, diarahkan untuk tetap menyimpan HP di tas, dan memperhatikan praktikan yang sedang diuji
# 3. Praktikan yang mendapatkan giliran ujian, memberikan kertas tersebut, dan mempraktekannya, mengikuti langkah berikut
# 4. Praktikan diberikan sebuah volume dgn satuan µl.
# 5. Asisten memperhatikan bagaimana praktikan menggunakan mikropipet sesuai kriteria
#
#
#
# Bagi yang tidak lulus, diperkenankan untuk mencoba lagi setelah semua praktikan telah mencoba.
# Namun, apabila waktu tidak mencukupi,
# maka praktikan mengadakan janji dengan asisten untuk diujikan di luar jam praktikum.
# Janji bisa dilakukan kapan saja, yang penting harus lulus sebelum acara selanjutnya.

# %% [markdown]
# #### Kriteria Penilaian
#
# :::{tip} Kriteria penilaian yang tercatat adalah untuk memperjelas kriteria yang asli
# :class: dropdown
#
# Catatan Awal Kriteria:
#
# 1. Cara memutar (tidak melebihi batas max, BISA BACA MAX VOLUMENYA BRP)
# 2. Cara mengatur (ngambil volume yg berapa berapa uL dulu sampai dapet volume target)
# 3. Ketepatan (bener pilih tip nya dan total volumenya betul gak)
# 4. Cara menggunakan setelah dipakai: melepas tip + balikin ke volume max
#
# :::
#
# Ujian dilakukan selama 5 menit untuk tiap praktikan.
# Nilai dari kriteria hanya berupa benar (✔️)/salah (❌).
# Kalau praktikan melebihi 5 menit, atau, selesai kurang dari 5 menit tapi ada yang salah, maka tidak diluluskan
#
# 1. Kesesuaian memutar volume adjustment  (nomor 1)
#    - Tidak melebihi batas
#    - Mampu membaca volumeter
# 2. Kesesuaian tip (nomor 3)
#    - Mampu memilih tip yang sesuai untuk ukuran tertentu
# 3. Mampu menggunakan berbagai ukuran mikropipet untuk mendapatkan volume target (nomor 2 dan 3)
# 4. Ketepatan mengikuti prosedur (nomor 4)

# %% [markdown]
# ## Post Test

# %% [markdown]
# ## Penutup
